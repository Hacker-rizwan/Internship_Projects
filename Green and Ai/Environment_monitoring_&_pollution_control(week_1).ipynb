# %% [markdown]
# # " **Pollution** **Source** **Detection** --AIR POLLUTION"

# %% [markdown]
# Dataset 1 – global_air_pollution_dataset.csv

# %%
#Week 1 Project: Pollution Source Detection
# Dataset 1: Global Air Pollution

# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Load dataset
df= pd.read_csv("global_air_pollution_dataset.csv")

# %%
# Step 3: Explore dataset
print("===== Global Air Pollution Dataset =====")
print("The data show the top 5 columns of the dataset")
# Out:
# ===== Global Air Pollution Dataset =====
# The data show the top 5 columns of the dataset

# %%
display(df.head())
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %%
print("Dataset Info:")
print("It shows the information of the data EG : Column name,No of elements,dtype\n")
df.info()
# Out:
# Dataset Info:
# It shows the information of the data EG : Column name,No of elements,dtype
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
print("\nDescriptive Statistics:")
print("\nIt shows the statistical summary of the data\n")
display(df.describe(include="all"))
# Out:
# Descriptive Statistics:
#
# It shows the statistical summary of the data
#                          Country    City     AQI Value AQI Category  \
# count                      23036   23462  23463.000000        23463
# unique                       175   23462           NaN            6
# top     United States of America  Marang           NaN         Good
# freq                        2872       1           NaN         9936
# mean                         NaN     NaN     72.010868          NaN
# std                          NaN     NaN     56.055220          NaN
# min                          NaN     NaN      6.000000          NaN
# 25%                          NaN     NaN     39.000000          NaN
# 50%                          NaN     NaN     55.000000          NaN
# 75%                          NaN     NaN     79.000000          NaN
# max                          NaN     NaN    500.000000          NaN
#
#         CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
# Step 4: Visualization of missing values
plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap - Global Air Pollution")
plt.show()

# %% [markdown]
# Dataset 2 – Air_quality_data_2019.xlsx

# %%
# Step 1: Load dataset
df1 = pd.read_excel("Air_quality_data_2019.xlsx")
display(df1.head())
# Out:
#   AMBIENT AIR QUALITY MONITORING DATA FOR THE YEAR 2019\n(Manual monitoring under National Ambient Air Quality Monitoring Programme)  \
# 0                             Sulphur Dioxide (SO2):
# 1                                         State / UT
# 2                                                NaN
# 3                                     Andhra Pradesh
# 4                                                NaN
#
#             Unnamed: 1                           Unnamed: 2  \
# 0                  NaN                                  NaN
# 1  City/ Town/ Village                             Location
# 2                  NaN                                  NaN
# 3            Anantapur                         Kamala Nagar
# 4                  NaN  APIIC Zonl office industrial estate
#
#                Unnamed: 3                   Unnamed: 4  \
# 0                     NaN                          NaN
# 1  No. of monitoring days  SO2  Concentration in µg/m3
# ...

# %%
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
print("\nDescriptive Statistics:")
display(df.describe(include="all"))
# Out:
# Descriptive Statistics:
#                          Country    City     AQI Value AQI Category  \
# count                      23036   23462  23463.000000        23463
# unique                       175   23462           NaN            6
# top     United States of America  Marang           NaN         Good
# freq                        2872       1           NaN         9936
# mean                         NaN     NaN     72.010868          NaN
# std                          NaN     NaN     56.055220          NaN
# min                          NaN     NaN      6.000000          NaN
# 25%                          NaN     NaN     39.000000          NaN
# 50%                          NaN     NaN     55.000000          NaN
# 75%                          NaN     NaN     79.000000          NaN
# max                          NaN     NaN    500.000000          NaN
#
#         CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
# Step 3: Visualization of missing values
plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap - Air Quality 2019")
plt.show()

# %% [markdown]
# Dataset 3 – Air_quality_data_2020.xlsx

# %%
# Step 1: Load dataset
df = pd.read_excel("Air_quality_data_2020.xlsx")

# %%
# Step 2: Explore dataset
print("===== Air Quality Dataset 2020 =====")

print("\nSample Data:")
display(df.head())
# Out:
# ===== Air Quality Dataset 2020 =====
#
# Sample Data:
#   AMBIENT AIR QUALITY MONITORING DATA FOR THE YEAR 2020\n(Manual monitoring under National Ambient Air Quality Monitoring Programme)  \
# 0                             Sulphur Dioxide (SO2):
# 1                                         State / UT
# 2                                                NaN
# 3                                     Andhra Pradesh
# 4                                                NaN
#
#           Unnamed: 1                           Unnamed: 2  \
# 0                NaN                                  NaN
# 1  City/Town/Village                             Location
# 2                NaN                                  NaN
# 3          Anantapur                         Kamala Nagar
# 4                NaN  APIIC Zonl office industrial estate
#
#                      Unnamed: 3                    Unnamed: 4      Unnamed: 5
# 0                           NaN                           NaN             NaN
# ...

# %%
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 6 columns):
#  #   Column                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                             --------------  -----
#  0   AMBIENT AIR QUALITY MONITORING DATA FOR THE YEAR 2020
# (Manual monitoring under National Ambient Air Quality Monitoring Programme)  28 non-null     object
#  1   Unnamed: 1                                                                                                                         299 non-null    object
#  2   Unnamed: 2                                                                                                                         685 non-null    object
# ...

# %%
print("\nDescriptive Statistics:")
display(df.describe(include="all"))
# Out:
# Descriptive Statistics:
#        AMBIENT AIR QUALITY MONITORING DATA FOR THE YEAR 2020\n(Manual monitoring under National Ambient Air Quality Monitoring Programme)  \
# count                                                  28
# unique                                                 28
# top                                Sulphur Dioxide (SO2):
# freq                                                    1
#
#        Unnamed: 1             Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# count         299                    685         686         685         685
# unique        299                    680          18          55          29
# top      Uluberia  KSPCB Office Premises           2           2           2
# freq            1                      3         220          63         102

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# AMBIENT AIR QUALITY MONITORING DATA FOR THE YEAR 2020\n(Manual monitoring under National Ambient Air Quality Monitoring Programme)    659
# Unnamed: 1                                                                                                                            388
# Unnamed: 2                                                                                                                              2
# Unnamed: 3                                                                                                                              1
# Unnamed: 4                                                                                                                              2
# Unnamed: 5                                                                                                                              2
# dtype: int64

# %%
# Step 3: Visualization of missing values
plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap - Air Quality 2020")
plt.show()
